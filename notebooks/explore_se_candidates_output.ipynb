# %%
# Adicionando ao path para importar funções do src
import sys
sys.path.append('../')

# %%
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import snscrape.modules.twitter as sntwitter
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from tqdm import tqdm

from src.filters import drop_duplicate_rows, drop_nans

# Oculta warnings do notebook
# import warnings
# warnings.filterwarnings('ignore')

# Configurações de visualização
pd.set_option('display.max_columns', 30)
pd.options.display.float_format = '{:,.2f}'.format

# %%
dataset_path = 'data/processed/'

se_1_df = pd.read_csv(f"{dataset_path}se_candidates_output_1.csv", sep=';')
se_2_df = pd.read_csv(f"{dataset_path}se_candidates_output_2.csv", sep=';')
se_3_df = pd.read_csv(f"{dataset_path}se_candidates_output_3.csv", sep=';')
print(se_1_df.shape, se_2_df.shape, se_3_df.shape)
# Out:
# (29357, 73) (29357, 79) (29357, 80)

# %%
se_1_df.shape
# Out:
# (29357, 73)

# %%
def drop_nans(X, y=None, subset=None):
    return X.dropna(subset=subset)

# %%
pipeline = Pipeline(
    [
        ("remove_nulls", FunctionTransformer(drop_nans, kw_args={"subset": "DS_URL"})),
        ("remove_duplicates", DuplicateRowsRemover(subset='DS_URL'))
    ]
)

pipeline
# Out:
# Pipeline(steps=[('remove_nulls',
#                  FunctionTransformer(func=<function drop_nans at 0x7f1554488790>,
#                                      kw_args={'subset': 'DS_URL'})),
#                 ('remove_duplicates', DuplicateRowsRemover(subset='DS_URL'))])

# %%
df = pipeline.fit_transform(se_1_df)
df.shape
# Out:
# removendo 27 linhas repetidas
# (1277, 73), (1250, 73)
# (1250, 73)

# %%
df2 = se_1_df.dropna(subset=['DS_URL'])
df2.shape
# Out:
# (1277, 73)

# %%
se_1_df.DS_URL.notna().sum()
# Out:
# 1277

# %%
dataset_path = 'data/processed/'

se_1_df = pd.read_csv(f"{dataset_path}se_candidates_output_1.csv", sep=';')
se_2_df = pd.read_csv(f"{dataset_path}se_candidates_output_2.csv", sep=';')
se_3_df = pd.read_csv(f"{dataset_path}se_candidates_output_3.csv", sep=';')
print(se_1_df.shape, se_2_df.shape, se_3_df.shape)
# Out:
# (29357, 73) (29357, 79) (29357, 80)

# %%
print(se_1_df.info())
print(se_2_df.info())
print(se_3_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29357 entries, 0 to 29356
# Data columns (total 73 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     29357 non-null  object
#  1   HH_GERACAO                     29357 non-null  object
#  2   ANO_ELEICAO                    29357 non-null  int64
#  3   CD_TIPO_ELEICAO                29357 non-null  int64
#  4   NM_TIPO_ELEICAO                29357 non-null  object
#  5   NR_TURNO                       29357 non-null  int64
#  6   CD_ELEICAO                     29357 non-null  int64
#  7   DS_ELEICAO                     29357 non-null  object
#  8   DT_ELEICAO                     29357 non-null  object
#  9   TP_ABRANGENCIA                 29357 non-null  object
#  10  SG_UF                          29357 non-null  object
#  11  SG_UE                          29357 non-null  object
#  12  NM_UE                          29357 non-null  object
#  13  CD_CARGO                       29357 non-null  int64
#  14  DS_CARGO                       29357 non-null  object
#  15  SQ_CANDIDATO                   29357 non-null  int64
#  16  NR_CANDIDATO                   29357 non-null  int64
#  17  NM_CANDIDATO                   29357 non-null  object
#  18  NM_URNA_CANDIDATO              29357 non-null  object
#  19  NM_SOCIAL_CANDIDATO            29357 non-null  object
#  20  NR_CPF_CANDIDATO               29357 non-null  int64
#  21  NM_EMAIL                       29357 non-null  object
#  22  CD_SITUACAO_CANDIDATURA        29357 non-null  int64
#  23  DS_SITUACAO_CANDIDATURA        29357 non-null  object
#  24  CD_DETALHE_SITUACAO_CAND       29357 non-null  int64
#  25  DS_DETALHE_SITUACAO_CAND       29357 non-null  object
#  26  TP_AGREMIACAO                  29357 non-null  object
#  27  NR_PARTIDO                     29357 non-null  int64
#  28  SG_PARTIDO                     29357 non-null  object
#  29  NM_PARTIDO                     29357 non-null  object
#  30  NR_FEDERACAO                   29357 non-null  int64
#  31  NM_FEDERACAO                   29357 non-null  object
#  32  SG_FEDERACAO                   29357 non-null  object
#  33  DS_COMPOSICAO_FEDERACAO        29357 non-null  object
#  34  SQ_COLIGACAO                   29357 non-null  int64
#  35  NM_COLIGACAO                   29357 non-null  object
#  36  DS_COMPOSICAO_COLIGACAO        29357 non-null  object
#  37  CD_NACIONALIDADE               29357 non-null  int64
#  38  DS_NACIONALIDADE               29357 non-null  object
#  39  SG_UF_NASCIMENTO               29357 non-null  object
#  40  CD_MUNICIPIO_NASCIMENTO        29357 non-null  int64
#  41  NM_MUNICIPIO_NASCIMENTO        29357 non-null  object
#  42  DT_NASCIMENTO                  29331 non-null  object
#  43  NR_IDADE_DATA_POSSE            29331 non-null  float64
#  44  NR_TITULO_ELEITORAL_CANDIDATO  29357 non-null  int64
#  45  CD_GENERO                      29357 non-null  int64
#  46  DS_GENERO                      29357 non-null  object
#  47  CD_GRAU_INSTRUCAO              29357 non-null  int64
#  48  DS_GRAU_INSTRUCAO              29357 non-null  object
#  49  CD_ESTADO_CIVIL                29357 non-null  int64
#  50  DS_ESTADO_CIVIL                29357 non-null  object
#  51  CD_COR_RACA                    29357 non-null  int64
#  52  DS_COR_RACA                    29357 non-null  object
#  53  CD_OCUPACAO                    29357 non-null  int64
#  54  DS_OCUPACAO                    29357 non-null  object
#  55  VR_DESPESA_MAX_CAMPANHA        29357 non-null  float64
#  56  CD_SIT_TOT_TURNO               29357 non-null  int64
#  57  DS_SIT_TOT_TURNO               29357 non-null  object
#  58  ST_REELEICAO                   29357 non-null  object
#  59  ST_DECLARAR_BENS               29357 non-null  object
#  60  NR_PROTOCOLO_CANDIDATURA       29357 non-null  int64
#  61  NR_PROCESSO                    29357 non-null  int64
#  62  CD_SITUACAO_CANDIDATO_PLEITO   29357 non-null  int64
#  63  DS_SITUACAO_CANDIDATO_PLEITO   29357 non-null  object
#  64  CD_SITUACAO_CANDIDATO_URNA     29357 non-null  int64
#  65  DS_SITUACAO_CANDIDATO_URNA     29357 non-null  object
#  66  ST_CANDIDATO_INSERIDO_URNA     29357 non-null  object
#  67  NM_TIPO_DESTINACAO_VOTOS       29357 non-null  object
#  68  CD_SITUACAO_CANDIDATO_TOT      29357 non-null  int64
#  69  DS_SITUACAO_CANDIDATO_TOT      29357 non-null  object
#  70  ST_PREST_CONTAS                29357 non-null  object
#  71  DS_URL                         1277 non-null   object
#  72  TW_USER                        1277 non-null   object
# dtypes: float64(2), int64(27), object(44)
# memory usage: 16.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29357 entries, 0 to 29356
# Data columns (total 79 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     29357 non-null  object
#  1   HH_GERACAO                     29357 non-null  object
#  2   ANO_ELEICAO                    29357 non-null  int64
#  3   CD_TIPO_ELEICAO                29357 non-null  int64
#  4   NM_TIPO_ELEICAO                29357 non-null  object
#  5   NR_TURNO                       29357 non-null  int64
#  6   CD_ELEICAO                     29357 non-null  int64
#  7   DS_ELEICAO                     29357 non-null  object
#  8   DT_ELEICAO                     29357 non-null  object
#  9   TP_ABRANGENCIA                 29357 non-null  object
#  10  SG_UF                          29357 non-null  object
#  11  SG_UE                          29357 non-null  object
#  12  NM_UE                          29357 non-null  object
#  13  CD_CARGO                       29357 non-null  int64
#  14  DS_CARGO                       29357 non-null  object
#  15  SQ_CANDIDATO                   29357 non-null  int64
#  16  NR_CANDIDATO                   29357 non-null  int64
#  17  NM_CANDIDATO                   29357 non-null  object
#  18  NM_URNA_CANDIDATO              29357 non-null  object
#  19  NM_SOCIAL_CANDIDATO            29357 non-null  object
#  20  NR_CPF_CANDIDATO               29357 non-null  int64
#  21  NM_EMAIL                       29357 non-null  object
#  22  CD_SITUACAO_CANDIDATURA        29357 non-null  int64
#  23  DS_SITUACAO_CANDIDATURA        29357 non-null  object
#  24  CD_DETALHE_SITUACAO_CAND       29357 non-null  int64
#  25  DS_DETALHE_SITUACAO_CAND       29357 non-null  object
#  26  TP_AGREMIACAO                  29357 non-null  object
#  27  NR_PARTIDO                     29357 non-null  int64
#  28  SG_PARTIDO                     29357 non-null  object
#  29  NM_PARTIDO                     29357 non-null  object
#  30  NR_FEDERACAO                   29357 non-null  int64
#  31  NM_FEDERACAO                   29357 non-null  object
#  32  SG_FEDERACAO                   29357 non-null  object
#  33  DS_COMPOSICAO_FEDERACAO        29357 non-null  object
#  34  SQ_COLIGACAO                   29357 non-null  int64
#  35  NM_COLIGACAO                   29357 non-null  object
#  36  DS_COMPOSICAO_COLIGACAO        29357 non-null  object
#  37  CD_NACIONALIDADE               29357 non-null  int64
#  38  DS_NACIONALIDADE               29357 non-null  object
#  39  SG_UF_NASCIMENTO               29357 non-null  object
#  40  CD_MUNICIPIO_NASCIMENTO        29357 non-null  int64
#  41  NM_MUNICIPIO_NASCIMENTO        29357 non-null  object
#  42  DT_NASCIMENTO                  29331 non-null  object
#  43  NR_IDADE_DATA_POSSE            29331 non-null  float64
#  44  NR_TITULO_ELEITORAL_CANDIDATO  29357 non-null  int64
#  45  CD_GENERO                      29357 non-null  int64
#  46  DS_GENERO                      29357 non-null  object
#  47  CD_GRAU_INSTRUCAO              29357 non-null  int64
#  48  DS_GRAU_INSTRUCAO              29357 non-null  object
#  49  CD_ESTADO_CIVIL                29357 non-null  int64
#  50  DS_ESTADO_CIVIL                29357 non-null  object
#  51  CD_COR_RACA                    29357 non-null  int64
#  52  DS_COR_RACA                    29357 non-null  object
#  53  CD_OCUPACAO                    29357 non-null  int64
#  54  DS_OCUPACAO                    29357 non-null  object
#  55  VR_DESPESA_MAX_CAMPANHA        29357 non-null  float64
#  56  CD_SIT_TOT_TURNO               29357 non-null  int64
#  57  DS_SIT_TOT_TURNO               29357 non-null  object
#  58  ST_REELEICAO                   29357 non-null  object
#  59  ST_DECLARAR_BENS               29357 non-null  object
#  60  NR_PROTOCOLO_CANDIDATURA       29357 non-null  int64
#  61  NR_PROCESSO                    29357 non-null  int64
#  62  CD_SITUACAO_CANDIDATO_PLEITO   29357 non-null  int64
#  63  DS_SITUACAO_CANDIDATO_PLEITO   29357 non-null  object
#  64  CD_SITUACAO_CANDIDATO_URNA     29357 non-null  int64
#  65  DS_SITUACAO_CANDIDATO_URNA     29357 non-null  object
#  66  ST_CANDIDATO_INSERIDO_URNA     29357 non-null  object
#  67  NM_TIPO_DESTINACAO_VOTOS       29357 non-null  object
#  68  CD_SITUACAO_CANDIDATO_TOT      29357 non-null  int64
#  69  DS_SITUACAO_CANDIDATO_TOT      29357 non-null  object
#  70  ST_PREST_CONTAS                29357 non-null  object
#  71  DS_URL                         1277 non-null   object
#  72  TW_USER                        1277 non-null   object
#  73  TW_followersCount              1277 non-null   float64
#  74  TW_friendsCount                1277 non-null   float64
#  75  TW_statusesCount               1277 non-null   float64
#  76  TW_favouritesCount             1277 non-null   float64
#  77  TW_listedCount                 1277 non-null   float64
#  78  TW_mediaCount                  1277 non-null   float64
# dtypes: float64(8), int64(27), object(44)
# memory usage: 17.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29357 entries, 0 to 29356
# Data columns (total 80 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     29357 non-null  object
#  1   HH_GERACAO                     29357 non-null  object
#  2   ANO_ELEICAO                    29357 non-null  int64
#  3   CD_TIPO_ELEICAO                29357 non-null  int64
#  4   NM_TIPO_ELEICAO                29357 non-null  object
#  5   NR_TURNO                       29357 non-null  int64
#  6   CD_ELEICAO                     29357 non-null  int64
#  7   DS_ELEICAO                     29357 non-null  object
#  8   DT_ELEICAO                     29357 non-null  object
#  9   TP_ABRANGENCIA                 29357 non-null  object
#  10  SG_UF                          29357 non-null  object
#  11  SG_UE                          29357 non-null  object
#  12  NM_UE                          29357 non-null  object
#  13  CD_CARGO                       29357 non-null  int64
#  14  DS_CARGO                       29357 non-null  object
#  15  SQ_CANDIDATO                   29357 non-null  int64
#  16  NR_CANDIDATO                   29357 non-null  int64
#  17  NM_CANDIDATO                   29357 non-null  object
#  18  NM_URNA_CANDIDATO              29357 non-null  object
#  19  NM_SOCIAL_CANDIDATO            29357 non-null  object
#  20  NR_CPF_CANDIDATO               29357 non-null  int64
#  21  NM_EMAIL                       29357 non-null  object
#  22  CD_SITUACAO_CANDIDATURA        29357 non-null  int64
#  23  DS_SITUACAO_CANDIDATURA        29357 non-null  object
#  24  CD_DETALHE_SITUACAO_CAND       29357 non-null  int64
#  25  DS_DETALHE_SITUACAO_CAND       29357 non-null  object
#  26  TP_AGREMIACAO                  29357 non-null  object
#  27  NR_PARTIDO                     29357 non-null  int64
#  28  SG_PARTIDO                     29357 non-null  object
#  29  NM_PARTIDO                     29357 non-null  object
#  30  NR_FEDERACAO                   29357 non-null  int64
#  31  NM_FEDERACAO                   29357 non-null  object
#  32  SG_FEDERACAO                   29357 non-null  object
#  33  DS_COMPOSICAO_FEDERACAO        29357 non-null  object
#  34  SQ_COLIGACAO                   29357 non-null  int64
#  35  NM_COLIGACAO                   29357 non-null  object
#  36  DS_COMPOSICAO_COLIGACAO        29357 non-null  object
#  37  CD_NACIONALIDADE               29357 non-null  int64
#  38  DS_NACIONALIDADE               29357 non-null  object
#  39  SG_UF_NASCIMENTO               29357 non-null  object
#  40  CD_MUNICIPIO_NASCIMENTO        29357 non-null  int64
#  41  NM_MUNICIPIO_NASCIMENTO        29357 non-null  object
#  42  DT_NASCIMENTO                  29331 non-null  object
#  43  NR_IDADE_DATA_POSSE            29331 non-null  float64
#  44  NR_TITULO_ELEITORAL_CANDIDATO  29357 non-null  int64
#  45  CD_GENERO                      29357 non-null  int64
#  46  DS_GENERO                      29357 non-null  object
#  47  CD_GRAU_INSTRUCAO              29357 non-null  int64
#  48  DS_GRAU_INSTRUCAO              29357 non-null  object
#  49  CD_ESTADO_CIVIL                29357 non-null  int64
#  50  DS_ESTADO_CIVIL                29357 non-null  object
#  51  CD_COR_RACA                    29357 non-null  int64
#  52  DS_COR_RACA                    29357 non-null  object
#  53  CD_OCUPACAO                    29357 non-null  int64
#  54  DS_OCUPACAO                    29357 non-null  object
#  55  VR_DESPESA_MAX_CAMPANHA        29357 non-null  float64
#  56  CD_SIT_TOT_TURNO               29357 non-null  int64
#  57  DS_SIT_TOT_TURNO               29357 non-null  object
#  58  ST_REELEICAO                   29357 non-null  object
#  59  ST_DECLARAR_BENS               29357 non-null  object
#  60  NR_PROTOCOLO_CANDIDATURA       29357 non-null  int64
#  61  NR_PROCESSO                    29357 non-null  int64
#  62  CD_SITUACAO_CANDIDATO_PLEITO   29357 non-null  int64
#  63  DS_SITUACAO_CANDIDATO_PLEITO   29357 non-null  object
#  64  CD_SITUACAO_CANDIDATO_URNA     29357 non-null  int64
#  65  DS_SITUACAO_CANDIDATO_URNA     29357 non-null  object
#  66  ST_CANDIDATO_INSERIDO_URNA     29357 non-null  object
#  67  NM_TIPO_DESTINACAO_VOTOS       29357 non-null  object
#  68  CD_SITUACAO_CANDIDATO_TOT      29357 non-null  int64
#  69  DS_SITUACAO_CANDIDATO_TOT      29357 non-null  object
#  70  ST_PREST_CONTAS                29357 non-null  object
#  71  DS_URL                         1277 non-null   object
#  72  TW_USER                        1277 non-null   object
#  73  TW_followersCount              1277 non-null   float64
#  74  TW_friendsCount                1277 non-null   float64
#  75  TW_statusesCount               1277 non-null   float64
#  76  TW_favouritesCount             1277 non-null   float64
#  77  TW_listedCount                 1277 non-null   float64
#  78  TW_mediaCount                  1277 non-null   float64
#  79  TW_electionTweets              1277 non-null   float64
# dtypes: float64(9), int64(27), object(44)
# memory usage: 17.9+ MB
# None

# %%
se_3_df.TW_electionTweets.value_counts()
# Out:
# 0.00      893
# 5.00       13
# 1.00       11
# 3.00       11
# 2.00       11
#          ...
# 717.00      1
# 790.00      1
# 834.00      1
# 176.00      1
# 78.00       1
# Name: TW_electionTweets, Length: 202, dtype: int64

# %%
se_3_df[se_3_df.TW_electionTweets > 0]
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 102    10/04/2023   19:42:09         2022                2  ELEIÇÃO ORDINÁRIA
# 175    10/04/2023   19:42:09         2022                2  ELEIÇÃO ORDINÁRIA
# 194    10/04/2023   19:42:09         2022                2  ELEIÇÃO ORDINÁRIA
# 197    10/04/2023   19:42:09         2022                2  ELEIÇÃO ORDINÁRIA
# 235    10/04/2023   19:42:09         2022                2  ELEIÇÃO ORDINÁRIA
# ...           ...        ...          ...              ...                ...
# 14417  10/04/2023   19:42:09         2022                2  ELEIÇÃO ORDINÁRIA
# 14558  10/04/2023   19:42:09         2022                2  ELEIÇÃO ORDINÁRIA
# 14573  10/04/2023   19:42:09         2022                2  ELEIÇÃO ORDINÁRIA
# 14891  10/04/2023   19:42:09         2022                2  ELEIÇÃO ORDINÁRIA
# 14981  10/04/2023   19:42:09         2022                2  ELEIÇÃO ORDINÁRIA
#
#        NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 102           1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 175           1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 194           1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 197           1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 235           1         546  Eleições Gerais Estaduais 2022  02/10/2022
# ...         ...         ...                             ...         ...
# 14417         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 14558         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 14573         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 14891         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 14981         1         546  Eleições Gerais Estaduais 2022  02/10/2022
#
#       TP_ABRANGENCIA SG_UF SG_UE           NM_UE  CD_CARGO           DS_CARGO  \
# 102         ESTADUAL    SP    SP       SÃO PAULO         6   DEPUTADO FEDERAL
# 175         ESTADUAL    SP    SP       SÃO PAULO         7  DEPUTADO ESTADUAL
# 194         ESTADUAL    MG    MG    MINAS GERAIS         6   DEPUTADO FEDERAL
# 197         ESTADUAL    MG    MG    MINAS GERAIS         7  DEPUTADO ESTADUAL
# 235         ESTADUAL    MG    MG    MINAS GERAIS         7  DEPUTADO ESTADUAL
# ...              ...   ...   ...             ...       ...                ...
# 14417       ESTADUAL    SP    SP       SÃO PAULO         6   DEPUTADO FEDERAL
# 14558       ESTADUAL    ES    ES  ESPÍRITO SANTO         6   DEPUTADO FEDERAL
# 14573       ESTADUAL    RJ    RJ  RIO DE JANEIRO         6   DEPUTADO FEDERAL
# 14891       ESTADUAL    SP    SP       SÃO PAULO         6   DEPUTADO FEDERAL
# 14981       ESTADUAL    ES    ES  ESPÍRITO SANTO         7  DEPUTADO ESTADUAL
#
#        ...  DS_SITUACAO_CANDIDATO_URNA  ST_CANDIDATO_INSERIDO_URNA  \
# 102    ...                    DEFERIDO                         SIM
# 175    ...                    DEFERIDO                         SIM
# 194    ...                    DEFERIDO                         SIM
# 197    ...                    DEFERIDO                         SIM
# 235    ...                    DEFERIDO                         SIM
# ...    ...                         ...                         ...
# 14417  ...                    DEFERIDO                         SIM
# 14558  ...                    DEFERIDO                         SIM
# 14573  ...                    DEFERIDO                         SIM
# 14891  ...                    DEFERIDO                         SIM
# 14981  ...                    DEFERIDO                         SIM
#
#       NM_TIPO_DESTINACAO_VOTOS CD_SITUACAO_CANDIDATO_TOT  \
# 102                     Válido                         2
# 175                     Válido                         2
# 194                     Válido                         2
# 197                     Válido                         2
# 235                     Válido                         2
# ...                        ...                       ...
# 14417                   Válido                         2
# 14558                   Válido                         2
# 14573                   Válido                         2
# 14891                   Válido                         2
# 14981                   Válido                         2
#
#       DS_SITUACAO_CANDIDATO_TOT  ST_PREST_CONTAS  \
# 102                    Deferido                S
# 175                    Deferido                S
# 194                    Deferido                S
# 197                    Deferido                S
# 235                    Deferido                S
# ...                         ...              ...
# 14417                  Deferido                S
# 14558                  Deferido                S
# 14573                  Deferido                S
# 14891                  Deferido                S
# 14981                  Deferido                S
#
#                                                   DS_URL          TW_USER  \
# 102              https://www.twitter.com/fernandoholiday  fernandoholiday
# 175    https://twitter.com/alemustafa?t=G_7Or1xdWBQeP...       alemustafa
# 194                     https://twitter.com/vadinhobaiao     vadinhobaiao
# 197    https://www.twitter.com/https://twitter.com/gi...     gianzappella
# 235                       https://twitter.com/mariocaixa       mariocaixa
# ...                                                  ...              ...
# 14417                 https://www.twitter.com/motta_novo       motta_novo
# 14558                      https://twitter.com/brunaolly        brunaolly
# 14573              http://www.twitter.com/bianca_provida   bianca_provida
# 14891                  http://twitter.com/oeduardosallum   oeduardosallum
# 14981                https://twitter.com/scaramussalucas  scaramussalucas
#
#       TW_followersCount  TW_friendsCount TW_statusesCount TW_favouritesCount  \
# 102          465,913.00           637.00        16,913.00          15,163.00
# 175              554.00         2,207.00         5,757.00          37,872.00
# 194              361.00           801.00           890.00           3,394.00
# 197               89.00            37.00            89.00              52.00
# 235          543,673.00        15,632.00        11,988.00           2,649.00
# ...                 ...              ...              ...                ...
# 14417            162.00           305.00           683.00             533.00
# 14558         43,948.00           102.00        10,189.00             281.00
# 14573             12.00           115.00           101.00             213.00
# 14891            744.00           320.00         1,000.00           1,846.00
# 14981            299.00            98.00           455.00             200.00
#
#        TW_listedCount TW_mediaCount TW_electionTweets
# 102            589.00      2,783.00            444.00
# 175              1.00        383.00             11.00
# 194              0.00         38.00             38.00
# 197              0.00          2.00             19.00
# 235            910.00      2,079.00              4.00
# ...               ...           ...               ...
# 14417            2.00        124.00             31.00
# 14558          236.00        466.00             78.00
# 14573            0.00         34.00              9.00
# 14891            0.00        261.00            119.00
# 14981            0.00        142.00             71.00
#
# [384 rows x 80 columns]

# %%
se_2_df.TW_followersCount.value_counts()
# Out:
# 0.00        214
# 2.00         15
# 8.00         13
# 3.00         11
# 10.00        11
#            ...
# 1,554.00      1
# 1,485.00      1
# 8,244.00      1
# 1,674.00      1
# 1,070.00      1
# Name: TW_followersCount, Length: 773, dtype: int64

# %%
se_2_df[se_2_df.TW_followersCount == 0][['DS_URL', 'TW_USER', 'TW_followersCount']]
# Out:
#                                                   DS_URL           TW_USER  \
# 116           https://mobile.twitter.com/RodrigoCapelDr,   rodrigocapeldr,
# 512               https://www.twitter.com/ADAMARIOMAXIMO    adamariomaximo
# 544                     https://twitter.com/marcobuenofc      marcobuenofc
# 907                       https://twitter.com/alefrota77        alefrota77
# 908                         https://twitter.com/77_frota          77_frota
# ...                                                  ...               ...
# 28414  https://www.twitter.com/https:twitter.com/dris...      dris-camargo
# 28617  https://twitter.com/cleberbroch?s=21&t=LuTKEnP...       cleberbroch
# 28751           https://www.twitter.com/ivanorodriguesrj  ivanorodriguesrj
# 28954                  https://www.twitter.com/sgtzaqueu         sgtzaqueu
# 29040                       https://twitter.com/dcuriati          dcuriati
#
#        TW_followersCount
# 116                 0.00
# 512                 0.00
# 544                 0.00
# 907                 0.00
# 908                 0.00
# ...                  ...
# 28414               0.00
# 28617               0.00
# 28751               0.00
# 28954               0.00
# 29040               0.00
#
# [214 rows x 3 columns]

# %%
se_3_df[se_3_df.TW_electionTweets == 0][['DS_URL', 'TW_USER', 'TW_followersCount', 'TW_electionTweets']]
# Out:
#                                                   DS_URL          TW_USER  \
# 18                     https://twitter.com/niltoncandido    niltoncandido
# 107                 https://www.twitter.com/TaxiZapElite     taxizapelite
# 116           https://mobile.twitter.com/RodrigoCapelDr,  rodrigocapeldr,
# 162    https://twitter.com/LessaTenente?t=nqNj8fAySbh...     lessatenente
# 176                   https://twitter.com/depbrunafurlan   depbrunafurlan
# ...                                                  ...              ...
# 29203  https://twitter.com/laerciobenko?ref_src=twsrc...     laerciobenko
# 29228                https://twitter.com/fabiomagalhaes_  fabiomagalhaes_
# 29273                 https://twitter.com/ProfReinaldo13   profreinaldo13
# 29349  https://twitter.com/machado13rp?s=21&t=BSKc7yJ...      machado13rp
# 29355                   https://twitter.com/wilsonkmatos     wilsonkmatos
#
#        TW_followersCount  TW_electionTweets
# 18                 32.00               0.00
# 107               903.00               0.00
# 116                 0.00               0.00
# 162                49.00               0.00
# 176            11,876.00               0.00
# ...                  ...                ...
# 29203             548.00               0.00
# 29228             595.00               0.00
# 29273              68.00               0.00
# 29349           1,070.00               0.00
# 29355             129.00               0.00
#
# [893 rows x 4 columns]
